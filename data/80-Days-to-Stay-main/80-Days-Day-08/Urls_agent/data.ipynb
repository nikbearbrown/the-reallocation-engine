# %%
import pandas as pd 

df = pd.read_csv('data_websites.csv')

# %%
companies = df[:50]['company_name'].to_list()

# %%
companies
# Out:
# ['$AVY INC',
#  '011235813 INC',
#  '0XCORD INC',
#  '0XESSENTIAL INC',
#  '1 KICKER HOLDINGS LLC',
#  '1 N MAIN LLC',
#  '1 TRUE HEALTH CARE MANAGEMENT INC',
#  '1-10 LOGISTICS CENTER LLC',
#  '10 PERCENT HAPPIER INC',
#  '100 THIEVES LLC',
#  '10000 INC',
#  '1000MUSEUMS INC',
#  '100INSIGHTS INC',
#  '101 EDU INC',
#  '101 STUDIOS LLC',
#  '1031 CF BRIDGE FUND LLC',
#  '1031CF BRIDGE FUND II LLC',
#  '1034 WESTMORELAND LLC',
#  '1052 PARTNERS LLC',
#  '1080 LORIMER MEZZ INVESTORS LP',
#  '1080 NETWORK INC',
#  '10BEAUTY INC',
#  '10TALES INC',
#  '11 HONORE INC',
#  '11 RONIIN LLC',
#  '111 COMMERCIAL COURT INVESTORS LP',
#  '112 CAPITAL HH LLC',
#  '112 VENTURES LLC',
#  '1125 GARDEN STREET HOTEL INVESTORS LP',
#  '1136 31ST AVE S LLC',
#  '1155 ISLAND AVENUE LLC',
#  '1200 PHARMA LLC',
#  '122UP VENTURE LLC',
#  '123 SEE INC',
#  '1251 CAPITAL GROUP INC',
#  '128 MAIN STREET LLC',
#  '128 TECHNOLOGY INC',
#  '12TH AVE LENDERS LLC',
#  '13011 WIRE RD LP',
#  '13030 CAPE LP',
# ...

# %%
companies = df[50:55]['company_name'].to_list()

# %%
companies
# Out:
# ['1560 SHERMAN ST APARTMENTS LLC',
#  '15FIVE INC',
#  '16 PINS INC',
#  '16 QUIET BARS UPTOWN LTD LIABILITY CO',
#  '1601 STATE STREET HOTEL INVESTORS LP']
